# %% [markdown]
# # Reading Data

# %%
import pandas as pd

# Path to the file

file_path = 'C:/Users/bhagi/Unified_Mentor/uscensusbureau-big-game-census-data-visualization/All Places Census 2016 Population Estimates.xlsx'

# %%
# Read the Excel file
try:
    df = pd.read_excel(file_path)
except Exception as e:
    print(f"Error reading the file: {e}")

# %%
df.head()
# Out:
#       Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 0  1620000US0100124   100124            Abbeville city, Alabama
# 1  1620000US0100460   100460           Adamsville city, Alabama
# 2  1620000US0100484   100484              Addison town, Alabama
# 3  1620000US0100676   100676                Akron town, Alabama
# 4  1620000US0100820   100820            Alabaster city, Alabama
#
#   April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# 0                   2688                            2688
# 1                   4522                            4522
# 2                    758                             756
# 3                    356                             356
# 4                  30352                           31066
#
#    Population Estimate (as of July 1) - 2010  \
# 0                                       2683
# 1                                       4517
# 2                                        754
# 3                                        355
# 4                                      31176
#
#    Population Estimate (as of July 1) - 2011  \
# 0                                       2685
# 1                                       4495
# 2                                        753
# 3                                        345
# 4                                      31362
#
#    Population Estimate (as of July 1) - 2012  \
# 0                                       2647
# 1                                       4472
# 2                                        748
# 3                                        345
# 4                                      31663
#
#    Population Estimate (as of July 1) - 2013  \
# 0                                       2631
# 1                                       4447
# 2                                        748
# 3                                        342
# 4                                      31960
#
#    Population Estimate (as of July 1) - 2014  \
# 0                                       2619
# 1                                       4428
# 2                                        747
# 3                                        337
# 4                                      32167
#
#    Population Estimate (as of July 1) - 2015  \
# 0                                       2616
# 1                                       4395
# 2                                        740
# 3                                        337
# 4                                      32751
#
#    Population Estimate (as of July 1) - 2016
# 0                                       2603
# 1                                       4360
# 2                                        738
# 3                                        334
# 4                                      32948

# %% [markdown]
# # checking for null values

# %%
print(df.isnull().sum())
# Out:
# Geographic ID                                0
# GEOID 2                                      0
# Geography, full name (City, State)           0
# April 1, 2010 - Census                       0
# April 1, 2010 - Estimates Base               0
# Population Estimate (as of July 1) - 2010    0
# Population Estimate (as of July 1) - 2011    0
# Population Estimate (as of July 1) - 2012    0
# Population Estimate (as of July 1) - 2013    0
# Population Estimate (as of July 1) - 2014    0
# Population Estimate (as of July 1) - 2015    0
# Population Estimate (as of July 1) - 2016    0
# dtype: int64

# %% [markdown]
# # Transformation
# ## Convert the relevant columns to numeric types and handle any missing values or non-numeric entries.

# %%
# List of population columns
population_columns = [
    'April 1, 2010 - Census', 'April 1, 2010 - Estimates Base', 
    'Population Estimate (as of July 1) - 2010', 'Population Estimate (as of July 1) - 2011',
    'Population Estimate (as of July 1) - 2012', 'Population Estimate (as of July 1) - 2013',
    'Population Estimate (as of July 1) - 2014', 'Population Estimate (as of July 1) - 2015',
    'Population Estimate (as of July 1) - 2016'
]

# Convert population columns to numeric types
for col in population_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Display data types to confirm conversion
print(df.dtypes)
# Out:
# Geographic ID                                 object
# GEOID 2                                        int64
# Geography, full name (City, State)            object
# April 1, 2010 - Census                       float64
# April 1, 2010 - Estimates Base                 int64
# Population Estimate (as of July 1) - 2010      int64
# Population Estimate (as of July 1) - 2011      int64
# Population Estimate (as of July 1) - 2012      int64
# Population Estimate (as of July 1) - 2013      int64
# Population Estimate (as of July 1) - 2014      int64
# Population Estimate (as of July 1) - 2015      int64
# Population Estimate (as of July 1) - 2016      int64
# dtype: object

# %% [markdown]
# # Basics Statistics

# %%
# Calculate basic statistics
statistics = df[population_columns].describe()
print(statistics)
# Out:
#        April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# count            1.946400e+04                    1.951000e+04
# mean             9.873334e+03                    9.909960e+03
# std              8.017080e+04                    8.012455e+04
# min              0.000000e+00                    0.000000e+00
# 25%              3.680000e+02                    3.690000e+02
# 50%              1.144000e+03                    1.147000e+03
# 75%              4.565500e+03                    4.603250e+03
# max              8.175133e+06                    8.174962e+06
#
#        Population Estimate (as of July 1) - 2010  \
# count                               1.951000e+04
# mean                                9.930210e+03
# std                                 8.028673e+04
# min                                 0.000000e+00
# 25%                                 3.690000e+02
# 50%                                 1.148000e+03
# 75%                                 4.606000e+03
# max                                 8.192026e+06
#
#        Population Estimate (as of July 1) - 2011  \
# count                               1.951000e+04
# mean                                1.001311e+04
# std                                 8.113065e+04
# min                                 0.000000e+00
# 25%                                 3.682500e+02
# 50%                                 1.148000e+03
# 75%                                 4.620000e+03
# max                                 8.284098e+06
#
#        Population Estimate (as of July 1) - 2012  \
# count                               1.951000e+04
# mean                                1.009960e+04
# std                                 8.195162e+04
# min                                 0.000000e+00
# 25%                                 3.660000e+02
# 50%                                 1.147000e+03
# 75%                                 4.632500e+03
# max                                 8.361179e+06
#
#        Population Estimate (as of July 1) - 2013  \
# count                               1.951000e+04
# mean                                1.018003e+04
# std                                 8.265639e+04
# min                                 0.000000e+00
# 25%                                 3.662500e+02
# 50%                                 1.146500e+03
# 75%                                 4.648000e+03
# max                                 8.422460e+06
#
#        Population Estimate (as of July 1) - 2014  \
# count                               1.951000e+04
# mean                                1.026316e+04
# std                                 8.329606e+04
# min                                 0.000000e+00
# 25%                                 3.650000e+02
# 50%                                 1.145500e+03
# 75%                                 4.680000e+03
# max                                 8.471990e+06
#
#        Population Estimate (as of July 1) - 2015  \
# count                               1.951000e+04
# mean                                1.034566e+04
# std                                 8.389854e+04
# min                                 0.000000e+00
# 25%                                 3.650000e+02
# 50%                                 1.146500e+03
# 75%                                 4.700500e+03
# max                                 8.516502e+06
#
#        Population Estimate (as of July 1) - 2016
# count                               1.951000e+04
# mean                                1.042104e+04
# std                                 8.432409e+04
# min                                 0.000000e+00
# 25%                                 3.640000e+02
# 50%                                 1.149500e+03
# 75%                                 4.716500e+03
# max                                 8.537673e+06

# %% [markdown]
# # Population Trends Visualization
# ## Visualizing the population trends for a few selected cities

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(12, 8))

cities = df['Geography, full name (City, State)'].unique()[:5]  # Select a few cities for demonstration

for city in cities:
    city_data = df[df['Geography, full name (City, State)'] == city]
    plt.plot(population_columns, city_data[population_columns].values[0], label=city)

plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Trends')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Growth Rate Calculation
# ## Calculating the annual growth rate for each city

# %%
# Calculate annual growth rates manually
for i in range(len(population_columns) - 1):
    start_col = population_columns[i]
    end_col = population_columns[i + 1]
    growth_rate_col = f'{end_col}_growth_rate'
    df[growth_rate_col] = ((df[end_col] - df[start_col]) / df[start_col]) * 100

# Display the first few rows with growth rates
print(df.head())
# Out:
#       Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 0  1620000US0100124   100124            Abbeville city, Alabama
# 1  1620000US0100460   100460           Adamsville city, Alabama
# 2  1620000US0100484   100484              Addison town, Alabama
# 3  1620000US0100676   100676                Akron town, Alabama
# 4  1620000US0100820   100820            Alabaster city, Alabama
#
#   April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# 0                 2688.0                            2688
# 1                 4522.0                            4522
# 2                  758.0                             756
# 3                  356.0                             356
# 4                30352.0                           31066
#
#    Population Estimate (as of July 1) - 2010  \
# 0                                       2683
# 1                                       4517
# 2                                        754
# 3                                        355
# 4                                      31176
#
#    Population Estimate (as of July 1) - 2011  \
# 0                                       2685
# 1                                       4495
# 2                                        753
# 3                                        345
# 4                                      31362
#
#    Population Estimate (as of July 1) - 2012  \
# 0                                       2647
# 1                                       4472
# 2                                        748
# 3                                        345
# 4                                      31663
#
#    Population Estimate (as of July 1) - 2013  \
# 0                                       2631
# 1                                       4447
# 2                                        748
# 3                                        342
# 4                                      31960
#
#    Population Estimate (as of July 1) - 2014  \
# 0                                       2619
# 1                                       4428
# 2                                        747
# 3                                        337
# 4                                      32167
#
#    Population Estimate (as of July 1) - 2015  \
# 0                                       2616
# 1                                       4395
# 2                                        740
# 3                                        337
# 4                                      32751
#
#    Population Estimate (as of July 1) - 2016  \
# 0                                       2603
# 1                                       4360
# 2                                        738
# 3                                        334
# 4                                      32948
#
#   April 1, 2010 - Estimates Base_growth_rate  \
# 0                                        0.0
# 1                                        0.0
# 2                                  -0.263852
# 3                                        0.0
# 4                                   2.352399
#
#    Population Estimate (as of July 1) - 2010_growth_rate  \
# 0                                          -0.186012
# 1                                          -0.110571
# 2                                          -0.264550
# 3                                          -0.280899
# 4                                           0.354085
#
#    Population Estimate (as of July 1) - 2011_growth_rate  \
# 0                                           0.074543
# 1                                          -0.487049
# 2                                          -0.132626
# 3                                          -2.816901
# 4                                           0.596613
#
#    Population Estimate (as of July 1) - 2012_growth_rate  \
# 0                                          -1.415270
# 1                                          -0.511680
# 2                                          -0.664011
# 3                                           0.000000
# 4                                           0.959760
#
#    Population Estimate (as of July 1) - 2013_growth_rate  \
# 0                                          -0.604458
# 1                                          -0.559034
# 2                                           0.000000
# 3                                          -0.869565
# 4                                           0.938003
#
#    Population Estimate (as of July 1) - 2014_growth_rate  \
# 0                                          -0.456100
# 1                                          -0.427254
# 2                                          -0.133690
# 3                                          -1.461988
# 4                                           0.647685
#
#    Population Estimate (as of July 1) - 2015_growth_rate  \
# 0                                          -0.114548
# 1                                          -0.745257
# 2                                          -0.937082
# 3                                           0.000000
# 4                                           1.815525
#
#    Population Estimate (as of July 1) - 2016_growth_rate
# 0                                          -0.496942
# 1                                          -0.796359
# 2                                          -0.270270
# 3                                          -0.890208
# 4                                           0.601508

# %%
import matplotlib.pyplot as plt

# Select cities to plot
cities = df['Geography, full name (City, State)'].unique()[:5]

# Plotting growth rates for selected cities
plt.figure(figsize=(12, 8))

growth_rate_columns = [f'{col}_growth_rate' for col in population_columns[1:]]

for city in cities:
    city_data = df[df['Geography, full name (City, State)'] == city]
    plt.plot(growth_rate_columns, city_data[growth_rate_columns].values[0], label=city)

plt.xlabel('Year')
plt.ylabel('Annual Growth Rate (%)')
plt.title('Annual Population Growth Rates')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering Analysis
# ## Performing K-means clustering on the population data

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# Fill NA values with the mean of each column
df[population_columns] = df[population_columns].fillna(df[population_columns].mean())

# Scale the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[population_columns])

# Apply K-means clustering
kmeans = KMeans(n_clusters=3, random_state=10)
df['Cluster'] = kmeans.fit_predict(df_scaled)

# Visualize clusters
sns.pairplot(df, vars=population_columns, hue='Cluster', palette='viridis')
plt.show()
# Out:
# C:\Users\bhagi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\bhagi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
